# %%
import os
import pandas as pd
from sqlalchemy import create_engine

# Configurações do banco de dados
USER = "lighthouse"
PASSWORD = "lighthouse1"
HOST = "localhost"
PORT = "5430"
DATABASE = "LH_Nautical"
csv_folder_path = "../arquivos/"

# Cria a conexão com o PostgreSQL
db_url = f"postgresql://{USER}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}"
engine = create_engine(db_url)

print("-- Iniciando o carregamento dos arquivos no banco de dados. --\n\n")
# Lista todos os arquivos da pasta e filtra apenas os que terminam com .csv
for file_name in os.listdir(csv_folder_path):
    if file_name.endswith(".csv"):
        # Monta o caminho completo do arquivo
        file_path = os.path.join(csv_folder_path, file_name)
        
        # Pega o nome do arquivo sem a extensão .csv para usar como nome da tabela
        table_name = os.path.splitext(file_name)[0]
        
        try:
            # Lê o arquivo CSV
            df = pd.read_csv(file_path)
            
            # Insere os dados na tabela existente (append)
            df.to_sql(table_name, con=engine, if_exists="append", index=False)
            print(f"{file_name} carregado a tabela '{table_name}' com sucesso.")
        except Exception as e:
            print(f"Erro ao carregar {file_name}: {e}")
print("\n\n-- Todos os arquivos foram carregados com sucesso no banco de dados. --")
# Out:
# -- Iniciando o carregamento dos arquivos no banco de dados. --
#
#
# addresses.csv carregado a tabela 'addresses' com sucesso.
# attributes.csv carregado a tabela 'attributes' com sucesso.
# brands.csv carregado a tabela 'brands' com sucesso.
# categories.csv carregado a tabela 'categories' com sucesso.
# customers.csv carregado a tabela 'customers' com sucesso.
# employees.csv carregado a tabela 'employees' com sucesso.
# fiscal_invoices.csv carregado a tabela 'fiscal_invoices' com sucesso.
# goods_receipts.csv carregado a tabela 'goods_receipts' com sucesso.
# goods_receipt_items.csv carregado a tabela 'goods_receipt_items' com sucesso.
# locations.csv carregado a tabela 'locations' com sucesso.
# orders.csv carregado a tabela 'orders' com sucesso.
# order_items.csv carregado a tabela 'order_items' com sucesso.
# payments.csv carregado a tabela 'payments' com sucesso.
# products.csv carregado a tabela 'products' com sucesso.
# product_suppliers.csv carregado a tabela 'product_suppliers' com sucesso.
# product_variants.csv carregado a tabela 'product_variants' com sucesso.
# purchase_orders.csv carregado a tabela 'purchase_orders' com sucesso.
# purchase_order_items.csv carregado a tabela 'purchase_order_items' com sucesso.
# returns.csv carregado a tabela 'returns' com sucesso.
# return_items.csv carregado a tabela 'return_items' com sucesso.
# stock_levels.csv carregado a tabela 'stock_levels' com sucesso.
# stock_movements.csv carregado a tabela 'stock_movements' com sucesso.
# suppliers.csv carregado a tabela 'suppliers' com sucesso.
# variant_attribute_values.csv carregado a tabela 'variant_attribute_values' com sucesso.
#
#
# -- Todos os arquivos foram carregados com sucesso no banco de dados. --
